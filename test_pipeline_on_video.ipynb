# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
from pipeline import AveragingPipeline
from util import show_images
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

img = mpimg.imread('./test_images/test2.jpg')
pipeline = AveragingPipeline(img.shape)
with_lanes = pipeline.highlight_lane(img)
plt.imshow(with_lanes)

# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
out_small_clip_path = 'output_videos/project_video.mp4'
small_clip = VideoFileClip("test_videos/project_video.mp4").subclip(2,4)
out_small_clip = small_clip.fl_image(pipeline.highlight_lane) #NOTE: this function expects color images!!
# %time out_small_clip.write_videofile(out_small_clip_path, audio=False)
# Out:
# [MoviePy] >>>> Building video output_videos/project_video.mp4
# [MoviePy] Writing video output_videos/project_video.mp4
#  98%|█████████▊| 50/51 [00:09<00:00,  4.98it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: output_videos/project_video.mp4
#
# CPU times: user 11.3 s, sys: 2.12 s, total: 13.4 s
# Wall time: 10.8 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(out_small_clip_path))
# Out:
# <video width="960" height="540" controls>
#   <source src="output_videos/project_video.mp4">
# </video>

# %%
project_video_output = 'output_videos/project_video.mp4'
clip1 = VideoFileClip("test_videos/project_video.mp4")
white_clip = clip1.fl_image(pipeline.highlight_lane) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(project_video_output, audio=False)
# Out:
# [MoviePy] >>>> Building video output_videos/project_video.mp4
# [MoviePy] Writing video output_videos/project_video.mp4
# 100%|█████████▉| 1260/1261 [04:22<00:00,  4.64it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: output_videos/project_video.mp4
#
# CPU times: user 4min 51s, sys: 1min, total: 5min 51s
# Wall time: 4min 23s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(project_video_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="output_videos/project_video.mp4">
# </video>
