# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
from pipeline import AveragingPipeline
from util import show_images
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

img = mpimg.imread('./test_images/test2.jpg')
pipeline = AveragingPipeline(img.shape)
with_lanes = pipeline.highlight_lane(img)
plt.imshow(with_lanes)

# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
project_video_output = 'output_videos/project_video.mp4'
clip1 = VideoFileClip("test_videos/project_video.mp4")
white_clip = clip1.fl_image(pipeline.highlight_lane) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(project_video_output, audio=False)
# Out:
# [MoviePy] >>>> Building video output_videos/project_video.mp4
# [MoviePy] Writing video output_videos/project_video.mp4
#   0%|          | 0/1261 [00:00<?, ?it/s]
#
#   0%|          | 1/1261 [00:00<02:14,  9.37it/s]
#
#   0%|          | 2/1261 [00:00<02:11,  9.55it/s]
#
#   0%|          | 3/1261 [00:00<02:10,  9.61it/s]
#
#   0%|          | 5/1261 [00:00<02:08,  9.78it/s]
#
#   1%|          | 7/1261 [00:00<02:06,  9.89it/s]
#
#   1%|          | 8/1261 [00:00<02:08,  9.76it/s]
#
#   1%|          | 10/1261 [00:01<02:06,  9.86it/s]
#
#   1%|          | 11/1261 [00:01<02:09,  9.66it/s]
#
#   1%|          | 13/1261 [00:01<02:08,  9.73it/s]
#
#   1%|          | 14/1261 [00:01<02:09,  9.63it/s]
#
#   1%|          | 15/1261 [00:01<02:08,  9.68it/s]
#
#   1%|▏         | 17/1261 [00:01<02:07,  9.76it/s]
#
#   1%|▏         | 18/1261 [00:01<02:06,  9.80it/s]
#
#   2%|▏         | 19/1261 [00:01<02:06,  9.85it/s]
#
#   2%|▏         | 21/1261 [00:02<02:04,  9.94it/s]
#
#   2%|▏         | 23/1261 [00:02<02:03, 10.01it/s]
#
#   2%|▏         | 25/1261 [00:02<02:02, 10.09it/s]
#
#   2%|▏         | 27/1261 [00:02<02:01, 10.13it/s]
#
#   2%|▏         | 29/1261 [00:02<02:01, 10.13it/s]
#
#   2%|▏         | 31/1261 [00:03<02:01, 10.12it/s]
#
#   3%|▎         | 33/1261 [00:03<02:00, 10.23it/s]
#
#   3%|▎         | 35/1261 [00:03<01:59, 10.28it/s]
#
#   3%|▎         | 37/1261 [00:03<01:58, 10.32it/s]
#
#   3%|▎         | 39/1261 [00:03<01:58, 10.33it/s]
#
#   3%|▎         | 41/1261 [00:04<01:58, 10.33it/s]
#
#   3%|▎         | 43/1261 [00:04<01:58, 10.28it/s]
#
#   4%|▎         | 45/1261 [00:04<01:58, 10.25it/s]
#
#   4%|▎         | 47/1261 [00:04<01:58, 10.24it/s]
#
#   4%|▍         | 49/1261 [00:04<01:58, 10.26it/s]
#
#   4%|▍         | 51/1261 [00:05<01:57, 10.26it/s]
#
#   4%|▍         | 53/1261 [00:05<01:57, 10.30it/s]
#
#   4%|▍         | 55/1261 [00:05<01:57, 10.30it/s]
#
#   5%|▍         | 57/1261 [00:05<01:56, 10.29it/s]
#
#   5%|▍         | 59/1261 [00:05<01:57, 10.23it/s]
#
#   5%|▍         | 61/1261 [00:06<01:57, 10.25it/s]
#
#   5%|▍         | 63/1261 [00:06<01:58, 10.13it/s]
#
#   5%|▌         | 65/1261 [00:06<01:58, 10.09it/s]
#  48%|████▊     | 609/1261 [01:03<01:04, 10.06it/s]
#
#  48%|████▊     | 611/1261 [01:03<01:05,  9.98it/s]
# -----------------------
# TypeErrorTraceback (most recent call last)
# /Users/David/Workspace/udacity/sdcnd/CarND-Advanced-Lane-Lines/find_lines.py in find_line_from_prior(img, previous_line)
#      42     try:
# ---> 43         new_fit = fit_poly(img, active_indices)
#      44     except TypeError:
#
# /Users/David/Workspace/udacity/sdcnd/CarND-Advanced-Lane-Lines/find_lines.py in fit_poly(img, lane_indices)
#     156     y_indices = nonzero_y[lane_indices]
# --> 157     return np.polyfit(y_indices, x_indices, 2)
#     158
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     554     if x.size == 0:
# --> 555         raise TypeError("expected non-empty vector for x")
#     556     if y.ndim < 1 or y.ndim > 2:
#
# TypeError: expected non-empty vector for x
#
# During handling of the above exception, another exception occurred:
#
# LaneNotFoundExceptionTraceback (most recent call last)
# <ipython-input-6-fd9c64528d5f> in <module>()
#       2 clip1 = VideoFileClip("test_videos/project_video.mp4")
#       3 white_clip = clip1.fl_image(pipeline.highlight_lane) #NOTE: this function expects color images!!
# ----> 4 get_ipython().magic('time white_clip.write_videofile(project_video_output, audio=False)')
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1179         if mode=='eval':
#    1180             st = clock2()
# -> 1181             out = eval(code, glob, local_ns)
#    1182             end = clock2()
#    1183         else:
#
# <timed eval> in <module>()
#
# <decorator-gen-174> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-173> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     135              for (k,v) in k.items()}
#     136
# --> 137     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-172> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#     336                            audiofile = audiofile,
#     337                            verbose=verbose, threads=threads,
# --> 338                            ffmpeg_params=ffmpeg_params)
#     339
#     340         if remove_temp and make_audio:
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params)
#     214
#     215     for t,frame in clip.iter_frames(progress_bar=True, with_times=True,
# --> 216                                     fps=fps, dtype="uint8"):
#     217         if withmask:
#     218             mask = (255*clip.mask.get_frame(t))
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tqdm/_tqdm.py in __iter__(self)
#     831 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     832
# --> 833             for obj in iterable:
#     834                 yield obj
#     835                 # Update and print the progressbar.
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in generator()
#     471             for t in np.arange(0, self.duration, 1.0/fps):
#     472
# --> 473                 frame = self.get_frame(t)
#     474
#     475                 if (dtype is not None) and (frame.dtype != dtype):
#
# <decorator-gen-137> in get_frame(self, t)
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=[] , keep_duration=True):
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# /Users/David/anaconda/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in <lambda>(gf, t)
#     511         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     512         """
# --> 513         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     514
#     515     # --------------------------------------------------------------
#
# /Users/David/Workspace/udacity/sdcnd/CarND-Advanced-Lane-Lines/pipeline.py in highlight_lane(self, forward_view_img)
#      56             if len(self.left_lane_buffer) > 0:
#      57                 left_fit = find_line_from_prior(top_down, self.left_lane_buffer[0])
# ---> 58                 right_fit = find_line_from_prior(top_down, self.right_lane_buffer[0])
#      59             else:
#      60                 left_fit, right_fit, _ = find_lines_with_sliding_window(top_down)
#
# /Users/David/Workspace/udacity/sdcnd/CarND-Advanced-Lane-Lines/find_lines.py in find_line_from_prior(img, previous_line)
#      43         new_fit = fit_poly(img, active_indices)
#      44     except TypeError:
# ---> 45         raise LaneNotFoundException()
#      46     return new_fit
#      47     # ploty = np.linspace(0, img.shape[0] - 1, img.shape[0])
#
# LaneNotFoundException:

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(project_video_output))
